# %%
# Cell 1 — install Python deps
# !pip install -q ultralytics deep-sort-realtime lap cython_bbox
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 40.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 97.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 92.8 MB/s eta 0:00:00:00:010:01
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ...

# %%
# !python /kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav/benchmark_fps.py --tracker bytetrack --weights /kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav/best.pt --images-root /kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav/val/val
# Out:
# Device     : cuda
# Detector   : yolov8s  (/kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav/best.pt)
# Tracker    : bytetrack
# Sequence   : MultiUAV-002  (500 measured + 20 warmup frames)
# Building detector ...
# Building tracker  ...
# Running benchmark ...
# [csv] wrote outputs/fps/yolov8s_bytetrack_cuda.csv
# [csv] appended row to outputs/fps/summary.csv
#
# Results (n=500 measured frames, device=cuda):
#   Detector (yolov8s ): mean    8.53 ms | median    8.46 ms | p99    9.83 ms |  117.2 FPS
#   Tracker  (bytetrack): mean    4.48 ms | median    4.53 ms | p99    5.84 ms
#   End-to-end          : mean   13.01 ms |   76.9 FPS
#   Real-time: ✓ real-time (>= 25 FPS)

# %%
# !python /kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav/benchmark_fps.py --tracker deepsort --weights /kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav/best.pt --images-root /kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav/val/val
# Out:
# Device     : cuda
# Detector   : yolov8s  (/kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav/best.pt)
# Tracker    : deepsort
# Sequence   : MultiUAV-002  (500 measured + 20 warmup frames)
# Building detector ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Building tracker  ...
# Running benchmark ...
# [csv] wrote outputs/fps/yolov8s_deepsort_cuda.csv
# [csv] appended row to outputs/fps/summary.csv
#
# Results (n=500 measured frames, device=cuda):
#   Detector (yolov8s ): mean   17.23 ms | median   17.03 ms | p99   21.00 ms |   58.0 FPS
#   Tracker  (deepsort): mean 1059.46 ms | median 1067.60 ms | p99 1382.06 ms
#   End-to-end          : mean 1076.68 ms |    0.9 FPS
# ...

# %%
# Install YOLOX 0.3.0 (mirrors your inference notebook)
# %cd /kaggle/working
# !git clone --branch 0.3.0 --depth 1 https://github.com/Megvii-BaseDetection/YOLOX.git
# %cd /kaggle/working/YOLOX
# !pip install -q loguru thop ninja tabulate pycocotools
# !pip install -q -e . --no-deps
# %cd /kaggle/working
# Out:
# /kaggle/working
# Cloning into 'YOLOX'...
# remote: Enumerating objects: 216, done.
# remote: Counting objects: 100% (216/216), done.
# remote: Compressing objects: 100% (177/177), done.
# remote: Total 216 (delta 22), reused 109 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (216/216), 2.80 MiB | 30.53 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# Note: switching to '419778480ab6ec0590e5d3831b3afb3b46ab2aa3'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# ...

# %%
DS = "/kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav"
YX = "/kaggle/input/datasets/lazarvelinov46/uav-yolox-checkpoints"

# bytetrack
# !PYTHONPATH={DS} python {DS}/benchmark_fps.py \
    --detector yolox --tracker bytetrack \
    --weights {YX}/best_ckpt.pth \
    --exp-file {DS}/configs/yolox_uav_s.py \
    --images-root {DS}/val/val \
    --out /kaggle/working/outputs/fps

# deepsort
# !PYTHONPATH={DS} python {DS}/benchmark_fps.py \
    --detector yolox --tracker deepsort \
    --weights {YX}/best_ckpt.pth \
    --exp-file {DS}/configs/yolox_uav_s.py \
    --images-root {DS}/val/val \
    --out /kaggle/working/outputs/fps
# Out:
# Device     : cuda
# Detector   : yolox  (/kaggle/input/datasets/lazarvelinov46/uav-yolox-checkpoints/best_ckpt.pth)
# Tracker    : bytetrack
# Sequence   : MultiUAV-002  (500 measured + 20 warmup frames)
# Building detector ...
# Building tracker  ...
# Running benchmark ...
# [csv] wrote /kaggle/working/outputs/fps/yolox_bytetrack_cuda.csv
# [csv] appended row to /kaggle/working/outputs/fps/summary.csv
#
# Results (n=500 measured frames, device=cuda):
#   Detector (yolox   ): mean   12.36 ms | median   12.14 ms | p99   16.56 ms |   80.9 FPS
#   Tracker  (bytetrack): mean    4.41 ms | median    4.41 ms | p99    6.39 ms
#   End-to-end          : mean   16.77 ms |   59.6 FPS
#   Real-time: ✓ real-time (>= 25 FPS)
# Device     : cuda
# Detector   : yolox  (/kaggle/input/datasets/lazarvelinov46/uav-yolox-checkpoints/best_ckpt.pth)
# Tracker    : deepsort
# Sequence   : MultiUAV-002  (500 measured + 20 warmup frames)
# Building detector ...
# Building tracker  ...
# Running benchmark ...
# ...

# %%
# yolov8s + cmc
DS = "/kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav"
YX = "/kaggle/input/datasets/lazarvelinov46/uav-yolox-checkpoints"
# !PYTHONPATH={DS} python {DS}/benchmark_fps.py \
    --detector yolov8s --tracker bytetrack_cmc \
    --weights {DS}/best.pt \
    --images-root {DS}/val/val \
    --out /kaggle/working/outputs/fps

# yolox + cmc
# !PYTHONPATH={DS} python {DS}/benchmark_fps.py \
    --detector yolox --tracker bytetrack_cmc \
    --weights {YX}/best_ckpt.pth \
    --exp-file {DS}/configs/yolox_uav_s.py \
    --images-root {DS}/val/val \
    --out /kaggle/working/outputs/fps
# Out:
# Device     : cuda
# Detector   : yolov8s  (/kaggle/input/datasets/lazarvelinov46/benchmark-fps-for-anti-uav/best.pt)
# Tracker    : bytetrack_cmc
# Sequence   : MultiUAV-002  (500 measured + 20 warmup frames)
# Building detector ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Building tracker  ...
# Running benchmark ...
# [csv] wrote /kaggle/working/outputs/fps/yolov8s_bytetrack_cmc_cuda.csv
# [csv] appended row to /kaggle/working/outputs/fps/summary.csv
#
# Results (n=500 measured frames, device=cuda):
#   Detector (yolov8s ): mean   15.51 ms | median   15.85 ms | p99   16.35 ms |   64.5 FPS
#   Tracker  (bytetrack_cmc): mean   21.13 ms | median   22.12 ms | p99   28.07 ms
# ...
